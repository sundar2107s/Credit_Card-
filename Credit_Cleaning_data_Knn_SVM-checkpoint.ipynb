# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_excel("Credit_Card1.xlsx")
df=pd.DataFrame(data)
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'x1', 'x2', 'x3', 'x4',
#        'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'Df'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID           30000 non-null int64
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null int64
# EDUCATION    30000 non-null int64
# MARRIAGE     30000 non-null int64
# AGE          30000 non-null int64
# PAY_0        30000 non-null int64
# PAY_2        30000 non-null int64
# PAY_3        30000 non-null int64
# PAY_4        30000 non-null int64
# PAY_5        30000 non-null int64
# PAY_6        30000 non-null int64
# x1           30000 non-null int64
# x2           30000 non-null int64
# x3           30000 non-null int64
# x4           30000 non-null int64
# x5           30000 non-null int64
# x6           30000 non-null int64
# x7           30000 non-null int64
# x8           30000 non-null int64
# x9           30000 non-null int64
# x10          30000 non-null int64
# x11          30000 non-null int64
# x12          30000 non-null object
# ...

# %%
a=df.groupby("Df")
a.describe().transpose()
# Out:
# Df                          0              1
# AGE       count  2.336400e+04    6636.000000
#           mean   3.541727e+01      35.725738
#           std    9.077355e+00       9.693438
#           min    2.100000e+01      21.000000
#           25%    2.800000e+01      28.000000
#           50%    3.400000e+01      34.000000
#           75%    4.100000e+01      42.000000
#           max    7.900000e+01      75.000000
# EDUCATION count  2.336400e+04    6636.000000
#           mean   1.841337e+00       1.894665
#           std    8.067800e-01       0.728096
#           min    0.000000e+00       1.000000
#           25%    1.000000e+00       1.000000
#           50%    2.000000e+00       2.000000
#           75%    2.000000e+00       2.000000
#           max    6.000000e+00       6.000000
# ID        count  2.336400e+04    6636.000000
#           mean   1.506489e+04   14773.781947
#           std    8.684552e+03    8571.616622
#           min    3.000000e+00       1.000000
# ...

# %%
df.describe().transpose()
# Out:
#              count           mean            std       min       25%  \
# ID         30000.0   15000.500000    8660.398374       1.0   7500.75
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX        30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION  30000.0       1.853133       0.790349       0.0      1.00
# MARRIAGE   30000.0       1.551867       0.521970       0.0      1.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# PAY_0      30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_2      30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_3      30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_4      30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_5      30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_6      30000.0      -0.291100       1.149988      -2.0     -1.00
# x1         30000.0   51223.330900   73635.860576 -165580.0   3558.75
# ...

# %%
df1=df[['x7', 'x8', 'x9', 'x10', 'x11','Df']]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df1.drop('Df',axis=1))
scaled_features = scaler.transform(df1.drop('Df',axis=1))
df_feat = pd.DataFrame(scaled_features,columns=new_data.columns[:-1])
df_feat.head()
# Out:
#          x7        x8        x9       x10       x11
# 0 -0.341942 -0.227086 -0.296801 -0.308063 -0.314136
# 1 -0.341942 -0.213588 -0.240005 -0.244230 -0.314136
# 2 -0.250292 -0.191887 -0.240005 -0.244230 -0.248683
# 3 -0.221191 -0.169361 -0.228645 -0.237846 -0.244166
# 4 -0.221191  1.335034  0.271165  0.266434 -0.269039

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = train_test_split(scaled_features,df1['Df'],
                                                    test_size=0.30)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[6195  871]
#  [1428  506]]
#              precision    recall  f1-score   support
#
#           0       0.81      0.88      0.84      7066
#           1       0.37      0.26      0.31      1934
#
# avg / total       0.72      0.74      0.73      9000

# %%
df["SEX"].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %%
sns.countplot(df["Df"],hue=df["SEX"])

# %%
trail=df[["x1",'x2','x3','x4','x5','SEX']]
sns.pairplot(trail,hue="SEX",vars={"x1",'x2','x3','x4','x5'},kind='scatter')

# %%
corrl=trail.corr()
corrl
# Out:
#            x1        x2        x3        x4        x5       SEX
# x1   1.000000  0.951484  0.892279  0.860272  0.829779 -0.033642
# x2   0.951484  1.000000  0.928326  0.892482  0.859778 -0.031183
# x3   0.892279  0.928326  1.000000  0.923969  0.883910 -0.024563
# x4   0.860272  0.892482  0.923969  1.000000  0.940134 -0.021880
# x5   0.829779  0.859778  0.883910  0.940134  1.000000 -0.017005
# SEX -0.033642 -0.031183 -0.024563 -0.021880 -0.017005  1.000000

# %%
sns.heatmap(corrl)

# %%
trail2=df[['x7','x8','x9','x10','x11','Df']]
sns.pairplot(trail2,hue="Df",vars={'x7','x8','x9','x10','x11'},kind='scatter',diag_kind='kde')

# %%
df['x13']=df['x1']-df['x7']
df['x13'].head()
# Out:
# 0     3913
# 1     2682
# 2    27721
# 3    44990
# 4     6617
# Name: x13, dtype: int64

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'x1', 'x2', 'x3', 'x4',
#        'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'Df', 'x13'],
#       dtype='object')

# %%
df['Df'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: Df, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Df'])

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.boxplot(x="Df",y="x10", data=trail2)
plt.subplot(2,3,2)
sns.boxplot(x="Df",y="x11", data=trail2)
plt.subplot(2,3,3)
sns.boxplot(x="Df",y="x9", data=trail2)
plt.subplot(2,3,4)
sns.boxplot(x="Df",y="x8", data=trail2)
plt.subplot(2,3,5)
sns.boxplot(x="Df",y="x7", data=trail2)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.distplot(df['x7'])
plt.subplot(2,3,2)
sns.distplot(df['x8'])
plt.subplot(2,3,3)
sns.distplot(df['x9'])
plt.subplot(2,3,4)
sns.distplot(df['x10'])
plt.subplot(2,3,5)
sns.distplot(df['x11'])

# %%
gb=df.groupby("Df")
gb.describe()["x8"]
# Out:
#       count         mean           std  min     25%     50%      75%  \
# Df
# 0   23364.0  6640.465074  25302.263601  0.0  1005.0  2247.5  5311.25
# 1    6636.0  3388.649638  11737.986064  0.0     0.0  1533.5  3309.75
#
#           max
# Df
# 0   1684259.0
# 1    358689.0

# %%
x=df[(df['x8']<6000) & (df['x9']<6000) & (df['x10']<6000) & (df['x11']<6000) & (df['x7']<6000)]
x.columns
x.to_excel('Cleaned_Credit.xlsx',index=False)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,3,1)
sns.distplot(x['x7'])
plt.subplot(2,3,2)
sns.distplot(x['x8'])
plt.subplot(2,3,3)
sns.distplot(x['x9'])
plt.subplot(2,3,4)
sns.distplot(x['x10'])
plt.subplot(2,3,5)
sns.distplot(x['x11'])

# %%
x.describe().transpose()
# Out:
#              count           mean            std       min       25%      50%  \
# ID         17650.0   14809.971331    8618.924372       1.0   7371.50  14779.0
# LIMIT_BAL  17650.0  127924.192635  109767.637017   10000.0  50000.00  90000.0
# SEX        17650.0       1.600850       0.489738       1.0      1.00      2.0
# EDUCATION  17650.0       1.913541       0.774182       0.0      1.00      2.0
# MARRIAGE   17650.0       1.555637       0.525181       0.0      1.00      2.0
# AGE        17650.0      35.273258       9.566936      21.0     27.00     34.0
# PAY_0      17650.0       0.117847       1.176836      -2.0      0.00      0.0
# PAY_2      17650.0      -0.024929       1.290688      -2.0     -1.00      0.0
# PAY_3      17650.0      -0.091558       1.292552      -2.0     -1.00      0.0
# PAY_4      17650.0      -0.173598       1.279468      -2.0     -1.00      0.0
# PAY_5      17650.0      -0.240907       1.247666      -2.0     -1.00      0.0
# ...

# %%
gb=x.groupby('Df')
gb.describe().transpose()
# Out:
# Df                           0              1
# AGE       count   12952.000000    4698.000000
#           mean       35.168005      35.563431
#           std         9.421513       9.952127
#           min        21.000000      21.000000
#           25%        27.000000      27.000000
#           50%        33.000000      34.000000
#           75%        41.000000      42.000000
#           max        75.000000      75.000000
# EDUCATION count   12952.000000    4698.000000
#           mean        1.906501       1.932950
#           std         0.794826       0.713906
#           min         0.000000       1.000000
#           25%         1.000000       1.000000
#           50%         2.000000       2.000000
#           75%         2.000000       2.000000
#           max         6.000000       6.000000
# ID        count   12952.000000    4698.000000
#           mean    14826.567480   14764.217114
#           std      8657.546625    8512.285201
# ...

# %%
sns.pairplot(x,hue="Df",vars={'x7','x8','x9','x10','x11'},kind='scatter',diag_kind='kde')

# %%
new_data=x[['x7','x8','x9','x10','x11','Df']]
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17650 entries, 0 to 29999
# Data columns (total 6 columns):
# x7     17650 non-null int64
# x8     17650 non-null int64
# x9     17650 non-null int64
# x10    17650 non-null int64
# x11    17650 non-null int64
# Df     17650 non-null int64
# dtypes: int64(6)
# memory usage: 1.6 MB

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,4,1)
sns.boxplot(x="Df",y="x10", data=new_data)
plt.subplot(2,4,2)
sns.boxplot(x="Df",y="x11", data=new_data)
plt.subplot(2,4,3)
sns.boxplot(x="Df",y="x8", data=new_data)
plt.subplot(2,4,4)
sns.boxplot(x="Df",y="x7", data=new_data)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(new_data.drop('Df',axis=1))
scaled_features = scaler.transform(new_data.drop('Df',axis=1))
df_feat = pd.DataFrame(scaled_features,columns=new_data.columns[:-1])
df_feat.head()
# Out:
#          x7        x8        x9       x10       x11
# 0 -1.164241 -0.670344 -1.023372 -0.939129 -0.928524
# 1 -1.164241 -0.458723 -0.293486 -0.192729 -0.928524
# 2 -0.159569 -0.118496 -0.293486 -0.192729 -0.187955
# 3  0.159437  0.234659 -0.147509 -0.118089 -0.136855
# 4  0.490357  0.095847 -0.543837 -0.192729 -0.187955

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
X_train, X_test, y_train, y_test = train_test_split(scaled_features,new_data['Df'],
                                                    test_size=0.30)
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[3194  742]
#  [ 972  387]]
#              precision    recall  f1-score   support
#
#           0       0.77      0.81      0.79      3936
#           1       0.34      0.28      0.31      1359
#
# avg / total       0.66      0.68      0.67      5295

# %%
from sklearn import metrics
confusion = metrics.confusion_matrix(y_test, pred)
TP = confusion[1, 1]
TN = confusion[0, 0]
FP = confusion[0, 1]
FN = confusion[1, 0]
#sensitivity 
print(metrics.recall_score(y_test, pred))
#specififty 
print(TN / float(TN + FP))
# Out:
# 0.2847682119205298
# 0.8114837398373984

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test,pred)
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Default classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)
print(metrics.roc_auc_score(y_test, pred))
# Out:
# 0.5481259758789641

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-0939b3473e07> in <module>()
#       2 fig.set_size_inches(15,5)
#       3
# ----> 4 plot_cm(ax[0],  y_train, pred, [0,1], 'Confusion matrix (TRAIN)')
#       5 plot_cm(ax[1],  y_test, pred,   [0,1], 'Confusion matrix (TEST)')
#       6 plot_auc(ax[2], y_train, pred, y_test, pred)
#
# NameError: name 'plot_cm' is not defined

# %%
#SVM Grid Search 
from sklearn.svm import SVC
model = SVC()
model.fit(X_train,y_train)
predictions = model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[3250    0]
#  [1163    0]]
#              precision    recall  f1-score   support
#
#           0       0.74      1.00      0.85      3250
#           1       0.00      0.00      0.00      1163
#
# avg / total       0.54      0.74      0.62      4413
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
param_grid = {'C': [0.1,1, 10, 100, 1000], 'gamma': [1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=3)
grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.7328348062542488, total=   1.7s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.7330009066183137, total=   1.6s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s remaining:    0.0s
# [CV]  C=0.1, gamma=1, kernel=rbf, score=0.7330009066183137, total=   1.7s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.7328348062542488, total=   1.5s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV]  C=0.1, gamma=0.1, kernel=rbf, score=0.7330009066183137, total=   1.5s
# ...

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'rbf'}

# %%
grid.best_estimator_
# Out:
# SVC(C=0.1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from sklearn.svm import SVC
model_1 = SVC(C=1,kernel='rbf',gamma=1)
model_1.fit(X_train,y_train)
predictions = model.predict(X_test)
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-c01e5d66829f> in <module>()
#       2 model_1 = SVC(C=1,kernel='rbf',gamma=1)
#       3 model_1.fit(X_train,y_train)
# ----> 4 predictions = model.predict(X_test)
#       5 from sklearn.metrics import classification_report,confusion_matrix
#       6 print(confusion_matrix(y_test,predictions))
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in predict(self, X)
#     546             Class labels for samples in X.
#     547         """
# --> 548         y = super(BaseSVC, self).predict(X)
#     549         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     550
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in predict(self, X)
#     306         y_pred : array, shape (n_samples,)
#     307         """
# --> 308         X = self._validate_for_predict(X)
# ...

# %%
#Knn-Decision Boundry plotting 
X=new_data.iloc[:,[0,1]].values
y=new_data.iloc[:,5].values

# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Visualising the Training set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('K-NN (Training set)')
plt.xlabel('X7')
plt.ylabel('X8')
plt.legend()
plt.show()

# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('K-NN (Test set)')
plt.xlabel('X7')
plt.ylabel('X8')
plt.legend()
plt.show()
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\LENOVO\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
sns.lmplot(x="AGE",y="LIMIT_BAL",data=df,hue="Df",markers=["o","+"])

# %%
sns.jointplot(x="AGE",y='LIMIT_BAL',data=df,kind="hex",size=10)

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'x1', 'x2', 'x3', 'x4',
#        'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'Df', 'x13'],
#       dtype='object')

# %%
df['PAY_0'].value_counts()
# Out:
#  0    14737
# -1     5686
#  1     3688
# -2     2759
#  2     2667
#  3      322
#  4       76
#  5       26
#  8       19
#  6       11
#  7        9
# Name: PAY_0, dtype: int64

# %%
#PCA(Princeple component Analysis)
#First we need to standardize the data to perform a PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
trail3=df[['x7','x8','x9','x10','x11']]

# %%
scaler=StandardScaler()
scaler.fit(trail3)
scaled_data=scaler.transform(trail3)
scaled_data1=pd.DataFrame(scaled_data)
scaled_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 5 columns):
# 0    30000 non-null float64
# 1    30000 non-null float64
# 2    30000 non-null float64
# 3    30000 non-null float64
# 4    30000 non-null float64
# dtypes: float64(5)
# memory usage: 1.1 MB

# %%
pca=PCA(n_components=5)
pca.fit(scaled_data)
plt.plot(pca.explained_variance_ratio_)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=scaled_data1[0],y=scaled_data1[1],data=scaled_data1,c=trail2['Df'])
plt.show()
#sns.jointplot(x=scaled_data1[0],y=scaled_data1[1],data=scaled_data1,type="scatter")

# %%
scaled_data1[0]
# Out:
# 0       -0.341942
# 1       -0.341942
# 2       -0.250292
# 3       -0.221191
# 4       -0.221191
# 5       -0.191003
# 6        2.978712
# 7       -0.318999
# 8       -0.140952
# 9       -0.341942
# 10      -0.202716
# 11       0.975331
# 12      -0.281566
# 13      -0.148740
# 14      -0.160815
# 15      -0.341942
# 16      -0.148740
# 17       0.283428
# 18      -0.341942
# 19      -0.341942
# 20      -0.160815
# 21      -0.322863
# 22      -0.220768
# 23       0.831034
# 24       0.005640
# 25      -0.222821
# 26      -0.341942
# 27      -0.263453
# 28      -0.135759
# 29      -0.251378
#            ...
# 29970    2.855003
# 29971   -0.197342
# 29972   -0.221191
# 29973   -0.341942
# 29974   -0.341942
# 29975    0.191778
# 29976   -0.100440
# 29977    0.080687
# 29978    0.263564
# 29979   -0.341942
# 29980    0.261814
# 29981   -0.203078
# 29982   -0.251378
# 29983   -0.167456
# 29984   -0.286215
# 29985   -0.341942
# 29986   -0.341942
# 29987   -0.160815
# 29988    3.582467
# ...

# %%
#KNN 
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaler.fit(trail2.drop('Df',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_feature=scaler.transform(trail2.drop("Df",axis=1))
normalized_data=pd.DataFrame(scaled_feature,columns=trail2.columns[:-1])
normalized_data.head()
# Out:
#          x7        x8        x9       x10       x11
# 0 -0.341942 -0.227086 -0.296801 -0.308063 -0.314136
# 1 -0.341942 -0.213588 -0.240005 -0.244230 -0.314136
# 2 -0.250292 -0.191887 -0.240005 -0.244230 -0.248683
# 3 -0.221191 -0.169361 -0.228645 -0.237846 -0.244166
# 4 -0.221191  1.335034  0.271165  0.266434 -0.269039

# %%
#Train and Test Data
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(scaled_feature,trail2['Df'],
                                                    test_size=0.30)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#Finding Optimum K value 
error_rate = []
for i in range(1,10):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,10),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0,0.5,'Error Rate')

# %%
#Fitting K-nn to training set
knn = KNeighborsClassifier(n_neighbors=4, metric='minkowski', p=2)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,pred))
# Out:
# [[6384  585]
#  [1685  346]]

# %%
print(classification_report(y_test,pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.79      0.92      0.85      6969
#           1       0.37      0.17      0.23      2031
#
# avg / total       0.70      0.75      0.71      9000

# %%
#Plotting the Classifier 
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
# X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
# plt.contourf(X1, X2, knn.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
# plt.xlim(X1.min(), X1.max())
# plt.ylim(X2.min(), X2.max())
# for i, j in enumerate(np.unique(y_set)):
#     plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
#                 c = ListedColormap(('red', 'green'))(i), label = j)
# plt.title('K-NN (Training set)')
# plt.xlabel('x7')
# plt.ylabel('x8')
# plt.legend()
# plt.show()

# %%
trail2.columns
# Out:
# Index(['x7', 'x8', 'x9', 'x10', 'x11', 'Df'], dtype='object')

# %%
#Knn Second try 
X = trail2[['x7','x8','x9','x10','x11']]
y = trail2['Df']

# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
# Out:
#            x7     x8     x9    x10    x11
# 12880    2000   2000   5000    438    780
# 14868    2343   2386   2296   1536   2451
# 14280   22500      0  10000   2600   2300
# 5318     8874   3567   1556   7952   4000
# 15421    8490   8100   8000   7804   8254
# 28136    1762   2311   2200    176    180
# 27264   10250   9278   7000   7000   5000
# 7260    14596  10705   3400   6410   5479
# 23032    3000   2000   2000   2000   2000
# 27827    8000   9000   5800   3505   3500
# 11631    3088   1500    651    682    680
# 6196     1712      0   3041      0   1326
# 23421    2177   2216   1879   1563   2000
# 25476    1000      0      0      0      0
# 29415     390    390    390   1438      0
# 5253      316    316    316    316    316
# 22073   55544    994   5030      0    500
# 13996    3600   2962   2500   1800   1000
# 7239     7762   7700      0   3545   3386
# 24193      15      0      0   5987      0
# 10166    1400   3000   2100   1200   1200
# ...

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)

# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[5402  466]
#  [1369  263]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.80      0.92      0.85      5868
#           1       0.36      0.16      0.22      1632
#
# avg / total       0.70      0.76      0.72      7500

# %%
# Visualising the Training set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('K-NN (Training set)')
plt.xlabel('X7')
plt.ylabel('X8')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-8a0d583f13d8> in <module>()
#       4 X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#       5                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
# ----> 6 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#       7              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
#       8 plt.xlim(X1.min(), X1.max())
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     143         X = check_array(X, accept_sparse='csr')
#     144
# --> 145         neigh_dist, neigh_ind = self.kneighbors(X)
#     146
#     147         classes_ = self.classes_
#
# ...

# %%
# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
# Out:
# 4511

# %%
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
# z= z.reshape(X2.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-053ab7dc8f36> in <module>()
# ----> 1 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#       2              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
#       3 # z= z.reshape(X2.shape)
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     143         X = check_array(X, accept_sparse='csr')
#     144
# --> 145         neigh_dist, neigh_ind = self.kneighbors(X)
#     146
#     147         classes_ = self.classes_
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in kneighbors(self, X, n_neighbors, return_distance)
#     383                 delayed(self._tree.query, check_pickle=False)(
#     384                     X[s], n_neighbors, return_distance)
# ...

# %%
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
# for i, j in enumerate(np.unique(y_set)):
#     plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
#                 c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('K-NN (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')#PCA(Princeple component Analysis)
#First we need to standardize the data to perform a PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
trail3=df[['x7','x8','x9','x10','x11']]
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-932f28574b0b> in <module>()
# ----> 1 plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#       2              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
#       3 plt.xlim(X1.min(), X1.max())
#       4 plt.ylim(X2.min(), X2.max())
#       5 # for i, j in enumerate(np.unique(y_set)):
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     143         X = check_array(X, accept_sparse='csr')
#     144
# --> 145         neigh_dist, neigh_ind = self.kneighbors(X)
#     146
#     147         classes_ = self.classes_
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in kneighbors(self, X, n_neighbors, return_distance)
#     383                 delayed(self._tree.query, check_pickle=False)(
# ...

# %%
#PCA(Princeple component Analysis)
#First we need to standardize the data to perform a PCA
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
trail3=df[['x7','x8','x9','x10','x11']]
pca=PCA(n_components=5)
pca.fit(scaled_data)
plt.plot(pca.explained_variance_ratio_)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=scaled_data1[0],y=scaled_data1[1],data=scaled_data1,c=trail2['Df'])
plt.show()
#sns.jointplot(
